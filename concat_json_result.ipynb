# %%
import pandas as pd

# %%
# !pip install openpyxl

# %%
df11 = pd.read_excel("json_result11-13-27.xlsx",engine='openpyxl')
df13 = pd.read_excel("json_result30-32-35err.xlsx",engine='openpyxl')
df27 = pd.read_excel("json_result36-38-40.xlsx",engine='openpyxl')
df30 = pd.read_excel("json_result58-60-65.xlsx",engine='openpyxl')
df32 = pd.read_excel("json_result66-69-70.xlsx",engine='openpyxl')
df35 = pd.read_excel("json_result72-73-74.xlsx",engine='openpyxl')
df36 = pd.read_excel("json_result75-76-77-78.xlsx",engine='openpyxl')

# %%
df = pd.df1= pd.concat([df11,df13,df27,df30,df32,df35,df36],axis = 0)

# %%
df_final = df[["id","classify","prob"]]
df_final_reset = df_final.set_index("id")
df_final_reset
# Out:
#                                                     classify      prob
# id
# ingo-images/Batch-transform-json-output/xdfp11-...         0  0.311132
# ingo-images/Batch-transform-json-output/xdfp11-...         0  0.049359
# ingo-images/Batch-transform-json-output/xdfp11-...         0  0.037111
# ingo-images/Batch-transform-json-output/xdfp11-...         0  0.610648
# ingo-images/Batch-transform-json-output/xdfp11-...         0  0.402225
# ...                                                      ...       ...
# ingo-images/Batch-transform-json-output/xdfp75-...         0  0.091665
# ingo-images/Batch-transform-json-output/xdfp75-...         0  0.076683
# ingo-images/Batch-transform-json-output/xdfp75-...         0  0.777770
# ingo-images/Batch-transform-json-output/xdfp75-...         0  0.583050
# ingo-images/Batch-transform-json-output/xdfp75-...         0  0.028607
#
# [2414223 rows x 2 columns]

# %%
df_final_reset.to_csv("json_final_table.csv")

# %%
df1= pd.concat([df11,df27,df30],axis = 0)

# %%
df1
# Out:
#         Unnamed: 0                                                 id  \
# 0                0  ingo-images/Batch-transform-json-output/xdfp11...
# 1                1  ingo-images/Batch-transform-json-output/xdfp11...
# 2                2  ingo-images/Batch-transform-json-output/xdfp11...
# 3                3  ingo-images/Batch-transform-json-output/xdfp11...
# 4                4  ingo-images/Batch-transform-json-output/xdfp11...
# ...            ...                                                ...
# 263783      263783  ingo-images/Batch-transform-json-output/xdfp58...
# 263784      263784  ingo-images/Batch-transform-json-output/xdfp58...
# 263785      263785  ingo-images/Batch-transform-json-output/xdfp58...
# 263786      263786  ingo-images/Batch-transform-json-output/xdfp58...
# 263787      263787  ingo-images/Batch-transform-json-output/xdfp58...
#
#         classify      prob
# 0              0  0.311132
# 1              0  0.049359
# 2              0  0.037111
# ...

# %%
df1.to_csv("json_final_table.csv")

# %%
df2= pd.concat([df35,df32],axis = 0)

# %%
df2
# Out:
#         Unnamed: 0                                                 id  \
# 0                0  ingo-images/Batch-transform-json-output/xdfp72...
# 1                1  ingo-images/Batch-transform-json-output/xdfp72...
# 2                2  ingo-images/Batch-transform-json-output/xdfp72...
# 3                3  ingo-images/Batch-transform-json-output/xdfp72...
# 4                4  ingo-images/Batch-transform-json-output/xdfp72...
# ...            ...                                                ...
# 510912      510912  ingo-images/Batch-transform-json-output/xdfp66...
# 510913      510913  ingo-images/Batch-transform-json-output/xdfp66...
# 510914      510914  ingo-images/Batch-transform-json-output/xdfp66...
# 510915      510915  ingo-images/Batch-transform-json-output/xdfp66...
# 510916      510916  ingo-images/Batch-transform-json-output/xdfp66...
#
#         classify      prob
# 0              0  0.044818
# 1              0  0.030633
# 2              0  0.029042
# ...

# %%
df2.to_csv("json_final_table.csv")

# %%
df3= pd.concat([df36],axis = 0)
df3
# Out:
#         Unnamed: 0                                                 id  \
# 0                0  ingo-images/Batch-transform-json-output/xdfp75...
# 1                1  ingo-images/Batch-transform-json-output/xdfp75...
# 2                2  ingo-images/Batch-transform-json-output/xdfp75...
# 3                3  ingo-images/Batch-transform-json-output/xdfp75...
# 4                4  ingo-images/Batch-transform-json-output/xdfp75...
# ...            ...                                                ...
# 161583      161583  ingo-images/Batch-transform-json-output/xdfp75...
# 161584      161584  ingo-images/Batch-transform-json-output/xdfp75...
# 161585      161585  ingo-images/Batch-transform-json-output/xdfp75...
# 161586      161586  ingo-images/Batch-transform-json-output/xdfp75...
# 161587      161587  ingo-images/Batch-transform-json-output/xdfp75...
#
#         classify      prob
# 0              0  0.023916
# 1              0  0.028501
# 2              0  0.024788
# ...

# %%
df3.to_csv("json_final_table3.csv")

# %%
df4 =  pd.concat([df13],axis = 0)
df4
# Out:
#         Unnamed: 0                                                 id  \
# 0                0  ingo-images/Batch-transform-json-output/xdfp30...
# 1                1  ingo-images/Batch-transform-json-output/xdfp30...
# 2                2  ingo-images/Batch-transform-json-output/xdfp30...
# 3                3  ingo-images/Batch-transform-json-output/xdfp30...
# 4                4  ingo-images/Batch-transform-json-output/xdfp30...
# ...            ...                                                ...
# 595957      595957  ingo-images/Batch-transform-json-output/xdfp30...
# 595958      595958  ingo-images/Batch-transform-json-output/xdfp30...
# 595959      595959  ingo-images/Batch-transform-json-output/xdfp30...
# 595960      595960  ingo-images/Batch-transform-json-output/xdfp30...
# 595961      595961  ingo-images/Batch-transform-json-output/xdfp30...
#
#         classify      prob
# 0              0  0.157763
# 1              0  0.043426
# 2              0  0.834217
# ...

# %%
df4.to_csv("json_final_table.csv")

# %%
df3= pd.concat([df66,df69,df70,df72,df73,df74,df75,df77],axis = 0)

# %%
df3
# Out:
#        Unnamed: 0 Protein        Tray    Date Observation Well  Well Position  \
# 0               0    xdfp  xdfp66-001  201113      HR0000  A01              1
# 1               1    xdfp  xdfp66-001  201113      HR0000  A01              2
# 2               2    xdfp  xdfp66-001  201113      HR0000  A01              3
# 3               3    xdfp  xdfp66-001  201113      HR0000  A02              1
# 4               4    xdfp  xdfp66-001  201113      HR0000  A02              2
# ...           ...     ...         ...     ...         ...  ...            ...
# 42070       42070    xdfp  xdfp77-012  210711      HR1230  H10              2
# 42071       42071    xdfp  xdfp77-012  210711      HR1230  H11              1
# 42072       42072    xdfp  xdfp77-012  210711      HR1230  H11              2
# 42073       42073    xdfp  xdfp77-012  210711      HR1230  H12              1
# 42074       42074    xdfp  xdfp77-012  210711      HR1230  H12              2
#
# ...

# %%
df3.to_excel("final_table4.xlsx")

# %%
df11=df11[['Protein', 'Tray', 'Date', 'Observation', 'Well',
       'Well Position', 'method', 'Time', 'After time', 'Full path']]

# %%
df32=df32[['Protein', 'Tray', 'Date', 'Obseravtion', 'Well',
       'Well Position', 'method', 'Time', 'After time', 'Full path']]

# %%
df32.columns=['Protein', 'Tray', 'Date', 'Observation', 'Well',
       'Well Position', 'method', 'Time', 'After time', 'Full path']

# %%
df5= pd.concat([df11,df32],ignore_index=True)

# %%
df5[['Time', 'After time', 'Full path']]
# Out:
#           Time  After time                                          Full path
# 0       190118           1  ingo-images/SMARCA2/Default/xdfp11-001/171114/...
# 1       190119           1  ingo-images/SMARCA2/Default/xdfp11-001/171114/...
# 2       190121           1  ingo-images/SMARCA2/Default/xdfp11-001/171114/...
# 3       190122           1  ingo-images/SMARCA2/Default/xdfp11-001/171114/...
# 4       190123           1  ingo-images/SMARCA2/Default/xdfp11-001/171114/...
# ...        ...         ...                                                ...
# 489918  192837           1  ingo-images/SMARCA2/Default/xdfp32-016/190306/...
# 489919  192829           1  ingo-images/SMARCA2/Default/xdfp32-016/190306/...
# 489920  192821           1  ingo-images/SMARCA2/Default/xdfp32-016/190306/...
# 489921  192812           1  ingo-images/SMARCA2/Default/xdfp32-016/190306/...
# 489922  192803           1  ingo-images/SMARCA2/Default/xdfp32-016/190306/...
#
# [489923 rows x 3 columns]

# %%
df5.to_excel("final_table5.xlsx")

# %%
s = "ingo-images/Batch-transform-json-output/xdfp11-13-27/cropped_xdfp11-001_A01-1_BASE_171115_080723_1.json.out"

# %%
s.rfind('xdfp')
# Out:
# 61

# %%
s.find('.json')
# Out:
# 98

# %%
SMARCA_condition = pd.read_csv("SMARCA2_condition_table.csv")
